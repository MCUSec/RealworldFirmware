# %% [markdown]
# # BinDatabase
#
# generate the database of functions based on the existed analyzed ghidra project

# %%
from utils.db import *
from utils.key import *
from utils.launcher import *
from utils.match import *

# %%
# start the Launcher 
launcher = HeadlessLoggingPyhidraLauncher(verbose=True, log_path='./launch.log')
launcher.start()
# Out:
# INFO  Using log config file: jar:file:/home/dingisoul/dev/FirmFlaw/ghidra_11.0_PUBLIC/Ghidra/Framework/Generic/lib/Generic.jar!/generic.log4j.xml (LoggingInitialization)
# INFO  Using log file: ./launch.log (LoggingInitialization)
# INFO  Loading user preferences: /home/dingisoul/.ghidra/.ghidra_11.0_PUBLIC/preferences (Preferences)
# INFO  Searching for classes... (ClassSearcher)
# INFO  Class search complete (1213 ms) (ClassSearcher)
# INFO  Initializing SSL Context (SSLContextInitializer)
# INFO  Initializing Random Number Generator... (SecureRandomFactory)
# INFO  Random Number Generator initialization complete: NativePRNGNonBlocking (SecureRandomFactory)
# INFO  Trust manager disabled, cacerts have not been set (ApplicationTrustManagerFactory)

# %%
# Reuse the project create or open in chapter 1 
# Necessary imports for ghidra project 
from ghidra.base.project import GhidraProject
from java.io import IOException
from pathlib import Path 

# Create Project Dir and name 
project_location = Path('./ghidra_project')
project_location.mkdir(exist_ok=True, parents=True)
project_name = "binmatch_project"

# create or open project 
try:
    project = GhidraProject.openProject(project_location, project_name, True)
    print(f'Opened project: {project.project.name}')
except IOException:
    project = GhidraProject.createProject(project_location, project_name, False)
    print(f'Created project: {project.project.name}')
# Out:
# INFO  Opening project: /home/dingisoul/dev/FirmFlaw/ghidra_project/binmatch_project (DefaultProject)
# Opened project: binmatch_project

# %%
# generate database for functions in binary 
from ghidra.program.flatapi import FlatProgramAPI
# from tqdm.notebook import tqdm
import os 
from functools import reduce
from operator import mul
# 
DATABASE = './step2_postSig/arm/bin_func.db'
if os.path.exists(DATABASE):
    print(f'remove {DATABASE}')
    os.remove(DATABASE)
conn = sqlite3.connect(DATABASE)
cursor = conn.cursor()
# if no database create the table and index 
sql_create_table(cursor,FUNC_KEYS,FUNC_TABLE_NAME)
sql_create_index(cursor,FUNC_TABLE_NAME,['hash'],'index_hash')
conn.commit()
num = 0
# use tqdm to generate the progress bar 
for file_ in project.getRootFolder().getFiles():
    # print(f"Match program {name_}")
    name_ = file_.getName()
    program = project.openProgram('/', name_, True)
    rows_ = []
    for func_ in program.getListing().getFunctions(True):
        if filter_func(func_):
            row_ = (func_.getName(),program.getName())
            inst_ = get_inst_key(func_)
            graph = get_struct_graph_key(func_)
            # make sure the inst_[0] means the numAddress 
            hash_ = reduce(mul,(n for n in graph),1) * inst_[0]
            #if hash_ >= 0xffffffff:
            #    print(f'WARNING: {func_.getName()} hash is a little long {hash_}')
            row_ += (hash_,) + inst_ + graph
            # no check because every bin is different 
            # if not sql_check_duplicate_func(cursor, row_[func_key_idx('name')], row_[func_key_idx('hash')], FUNC_TABLE_NAME):
            rows_.append(row_)
        # insert the rows    
    sql_insert(cursor, FUNC_KEYS.keys(), rows_, FUNC_TABLE_NAME)
    conn.commit()      
    # remember closing the program to avoid memory usage 
    print(f"{program.getName()} insert {len(rows_)} functions at {num}")
    num += 1
    project.close(program)
conn.close()
project.close()
# Out:
# remove ./step2_postSig/arm/bin_func.db
# CREATE TABLE IF NOT EXISTS func_table (id INTEGER PRIMARY KEY,name TEXT,program TEXT,hash INTEGER,numAddresses INTEGER,mnemonics TEXT,block_num INTEGER,edge_num INTEGER,call_num INTEGER,jump_num INTEGER);
# CREATE INDEX IF NOT EXISTS index_hash on func_table(hash);
# 0.hex.bin.fs109116fs.noheader insert 257 functions at 0
# 0.hex.bin.fs13848fs.noheader insert 16 functions at 1
# 0.hex.bin.fs162965fs.noheader insert 249 functions at 2
# 0.hex.bin.fs162965fs.noheader insert 0 functions at 3
# 0.hex.bin.fs177418fs.noheader insert 285 functions at 4
# 0.hex.bin.fs177418fs.noheader insert 0 functions at 5
# 0.hex.bin.fs177418fs.noheader insert 0 functions at 6
# 0.hex.bin.fs379885fs.noheader insert 154 functions at 7
# 0.hex.bin.fs445996fs.noheader insert 575 functions at 8
# 0.hex.bin.fs445996fs.noheader insert 0 functions at 9
# 0.hex.bin.fs510304fs.noheader insert 320 functions at 10
# 0.srec.bin.fs8384512fs.noheader insert 0 functions at 11
# 0.srec.bin.fs8384512fs.noheader insert 0 functions at 12
# 0.srec.bin.fs8384512fs.noheader insert 0 functions at 13
# 0.srec.bin.fs8384512fs.noheader insert 0 functions at 14
# 0.srec.bin.fs8384512fs.noheader insert 0 functions at 15
# 0.srec.bin.fs8384512fs.noheader insert 0 functions at 16
# 0.srec.bin.fs8384512fs.noheader insert 0 functions at 17
# 0.srec.bin.fs8384512fs.noheader insert 0 functions at 18
# A1-F08.bin.fs100352fs.noheader insert 447 functions at 19
# A1-F08.bin.fs100352fs.noheader insert 0 functions at 20
# A1-F08.bin.fs100352fs.noheader insert 0 functions at 21
# A2-F00.bin.fs157696fs.noheader insert 593 functions at 22
# AC6000Ble_APROM_V1.015_20201102_0312pmOpen.bin.fs64332fs.noheader insert 207 functions at 23
# AC6000C_MKIIIv2.001.bin.fs120384fs.noheader insert 241 functions at 24
# AC6000C_v1.007.bin.fs120960fs.noheader insert 198 functions at 25
# ACESCU_v1.003.bin.fs26368fs.noheader insert 143 functions at 26
# ACETarget_Voice_V1.006.bin.fs137216fs.noheader insert 0 functions at 27
# ACETarget_v2.026.bin.fs136192fs.noheader insert 509 functions at 28
# ACETarget_v2.031.bin.fs138240fs.noheader insert 499 functions at 29
# AKDP_RevE.bin.fs178860fs.noheader insert 952 functions at 30
# AS_360SSI_2_030.bin.fs654336fs.noheader insert 1036 functions at 31
# AZ-NM-101.bin.fs119104fs.noheader insert 0 functions at 32
# AZ-NM-102.bin.fs124464fs.noheader insert 0 functions at 33
# AZ-NM-103.bin.fs124286fs.noheader insert 0 functions at 34
# AZ-NM-104.bin.fs125583fs.noheader insert 0 functions at 35
# AZ-NM-105.bin.fs126042fs.noheader insert 0 functions at 36
# AZ-NM-106.bin.fs127462fs.noheader insert 0 functions at 37
# AZ-NM-107.bin.fs127718fs.noheader insert 0 functions at 38
# AZ-NM-108.bin.fs81518fs.noheader insert 0 functions at 39
# AZ-NM-110.bin.fs81682fs.noheader insert 0 functions at 40
# AZ-NM-111.bin.fs81714fs.noheader insert 0 functions at 41
# AZ-NM-112.bin.fs81634fs.noheader insert 0 functions at 42
# AZ-NM-114.bin.fs81886fs.noheader insert 0 functions at 43
# AZ-NM-115.bin.fs82256fs.noheader insert 0 functions at 44
# AZ-NM-116.bin.fs82670fs.noheader insert 0 functions at 45
# AZ-NM-117.bin.fs84182fs.noheader insert 0 functions at 46
# AZ-NM-119.bin.fs86696fs.noheader insert 0 functions at 47
# AZ-NM-202.bin.fs86862fs.noheader insert 0 functions at 48
# AZ-NM-203.bin.fs115486fs.noheader insert 0 functions at 49
# AZ-NM-204.bin.fs96488fs.noheader insert 0 functions at 50
# AZ-NM-205.bin.fs96526fs.noheader insert 0 functions at 51
# AZ-NM-208.bin.fs97566fs.noheader insert 0 functions at 52
# AZ-NM-212.bin.fs98330fs.noheader insert 0 functions at 53
# AZ-NM-216.bin.fs101318fs.noheader insert 0 functions at 54
# AZ-RS-102.bin.fs69222fs.noheader insert 0 functions at 55
# AZ-RS-103.bin.fs68569fs.noheader insert 0 functions at 56
# AZ-RS-104.bin.fs70663fs.noheader insert 0 functions at 57
# AZ-RS-105.bin.fs70423fs.noheader insert 0 functions at 58
# AZ-RS-106.bin.fs70429fs.noheader insert 0 functions at 59
# AZ-RS-107.bin.fs70429fs.noheader insert 0 functions at 60
# AZ-RS-108.bin.fs50224fs.noheader insert 0 functions at 61
# AZ-RS-109.bin.fs50798fs.noheader insert 0 functions at 62
# AZ-RS-200.bin.fs55052fs.noheader insert 0 functions at 63
# AZ-RS-201.bin.fs55064fs.noheader insert 0 functions at 64
# AZ-RS-202.bin.fs55094fs.noheader insert 0 functions at 65
# AZ-RS-203.bin.fs55156fs.noheader insert 0 functions at 66
# AZ-RS-204.bin.fs55059fs.noheader insert 0 functions at 67
# AZ-RS-205.bin.fs55077fs.noheader insert 0 functions at 68
# AZ-RS-206.bin.fs54648fs.noheader insert 0 functions at 69
# AZ-RS-207.bin.fs54652fs.noheader insert 0 functions at 70
# AZ-RS-208.bin.fs54876fs.noheader insert 0 functions at 71
# AZBI-LoRA-V307-13.bin.fs103824fs.noheader insert 0 functions at 72
# AZBI-LoRA-V307-14.bin.fs103888fs.noheader insert 0 functions at 73
# AZBI-LoRA-V307-15.bin.fs104132fs.noheader insert 0 functions at 74
# AZBI-LoRA-V307-16.bin.fs104676fs.noheader insert 0 functions at 75
# Aether_v2.021.bin.fs30848fs.noheader insert 117 functions at 76
# Bifrost_v1.010.bin.fs30592fs.noheader insert 194 functions at 77
# D1-U03.bin.fs45056fs.noheader insert 110 functions at 78
# D1-U03.bin.fs45056fs.noheader insert 0 functions at 79
# D1-U03.bin.fs45056fs.noheader insert 0 functions at 80
# D1-U03.bin.fs45056fs.noheader insert 0 functions at 81
# Diagnose.bin.fs14924fs.noheader insert 55 functions at 82
# EG_B0.bin.fs105472fs.noheader insert 312 functions at 83
# Encoder2Position.bin.fs45056fs.noheader insert 130 functions at 84
# FW_Upload_Test.bin.fs106120fs.noheader insert 341 functions at 85
# Genesis_v1.011.bin.fs44864fs.noheader insert 227 functions at 86
# HK_SB26.HUI.fs524080fs.noheader insert 1772 functions at 87
# K-log_Temperature_Logger.bin.fs60240fs.noheader insert 140 functions at 88
# LighterBTMKII_APROM_V2.001.bin.fs23936fs.noheader insert 159 functions at 89
# LighterBT_APROM_V1.015_APPTEST.bin.fs26956fs.noheader insert 144 functions at 90
# LighterBT_APROM_V1.018_20210408_0105pm.bin.fs27048fs.noheader insert 147 functions at 91
# LighterBT_APROM_V1.018_20210408_0105pm__1_.bin.fs27048fs.noheader insert 0 functions at 92
# LighterBT_APROM_V1.018_20210408_0105pm__2_.bin.fs27048fs.noheader insert 0 functions at 93
# P1-U04.bin.fs94208fs.noheader insert 398 functions at 94
# Pine_V3_1.bin.fs98248fs.noheader insert 197 functions at 95
# Pine_V3_2.bin.fs98976fs.noheader insert 191 functions at 96
# Pine_V3_3.bin.fs99080fs.noheader insert 190 functions at 97
# Pine_V3_4.bin.fs99112fs.noheader insert 193 functions at 98
# Pine_V3_5.bin.fs99112fs.noheader insert 0 functions at 99
# Pine_V3_6.bin.fs99560fs.noheader insert 231 functions at 100
# STM32-O-Scope.bin.fs39424fs.noheader insert 229 functions at 101
# STM32duinoBoot.bin.fs21140fs.noheader insert 86 functions at 102
# TRX-FMU-V2.bin.fs804500fs.noheader insert 2880 functions at 103
# TTL_Blink.bin.fs88084fs.noheader insert 209 functions at 104
# Teltail_HW_3v4.bin.fs112620fs.noheader insert 161 functions at 105
# Teltail_HW_4v1.bin.fs112144fs.noheader insert 146 functions at 106
# Teltail_HW_4v1_-_0v6.bin.fs105884fs.noheader insert 124 functions at 107
# TitleEdit.exe.fs131072fs.noheader insert 0 functions at 108
# UPGRADE_B1.bin.fs51200fs.noheader insert 138 functions at 109
# UPGRADE_B2.bin.fs51200fs.noheader insert 88 functions at 110
# WFPSM-02C_1.bin.fs63052fs.noheader insert 0 functions at 111
# WM100.bin.fs45476fs.noheader insert 209 functions at 112
# ac2k_12.61.00-000.21_20190514.bin.fs468704fs.noheader insert 183 functions at 113
# ac2k_12.61.00-000.25_3cfaa4f8__20191114.bin.fs443387fs.noheader insert 0 functions at 114
# ac5k_ex_small_30.63.01-000.19_11660164__20190419_01.bin.fs2357820fs.noheader insert 0 functions at 115
# af5.bin.fs73952fs.noheader insert 244 functions at 116
# app.bin.fs61936fs.noheader insert 154 functions at 117
# bcf-ethernet-climate-monitor-v1.0.1.bin.fs99628fs.noheader insert 477 functions at 118
# bcf-ethernet-climate-monitor-v1.0.2.bin.fs66992fs.noheader insert 360 functions at 119
# bcf-ethernet-climate-monitor-v1.0.3.bin.fs99628fs.noheader insert 22 functions at 120
# bcf-ethernet-climate-monitor-v1.1.0.bin.fs122396fs.noheader insert 591 functions at 121
# bcf-ethernet-climate-monitor-v1.1.1.bin.fs122524fs.noheader insert 467 functions at 122
# bcf-game-snake-v1.2.0.bin.fs41192fs.noheader insert 164 functions at 123
# bcf-gateway-core-module-v1.10.0.bin.fs144576fs.noheader insert 602 functions at 124
# bcf-gateway-core-module-v1.11.0.bin.fs144576fs.noheader insert 0 functions at 125
# bcf-gateway-core-module-v1.12.0.bin.fs145088fs.noheader insert 565 functions at 126
# bcf-gateway-core-module-v1.13.0.bin.fs145504fs.noheader insert 580 functions at 127
# bcf-gateway-core-module-v1.4.1.bin.fs133400fs.noheader insert 482 functions at 128
# bcf-gateway-core-module-v1.5.0.bin.fs133528fs.noheader insert 439 functions at 129
# bcf-gateway-core-module-v1.7.2.bin.fs137608fs.noheader insert 482 functions at 130
# bcf-gateway-core-module-v1.7.3.bin.fs137672fs.noheader insert 476 functions at 131
# bcf-gateway-core-module-v1.7.4.bin.fs137400fs.noheader insert 446 functions at 132
# bcf-gateway-core-module-v1.8.0.bin.fs138328fs.noheader insert 494 functions at 133
# bcf-gateway-core-module-v1.9.0.bin.fs140352fs.noheader insert 519 functions at 134
# bcf-gateway-usb-dongle-v1.10.0.bin.fs93104fs.noheader insert 535 functions at 135
# bcf-gateway-usb-dongle-v1.11.0.bin.fs93104fs.noheader insert 0 functions at 136
# bcf-gateway-usb-dongle-v1.12.0.bin.fs93552fs.noheader insert 495 functions at 137
# bcf-gateway-usb-dongle-v1.13.0.bin.fs94048fs.noheader insert 513 functions at 138
# bcf-gateway-usb-dongle-v1.7.2.bin.fs86148fs.noheader insert 454 functions at 139
# bcf-gateway-usb-dongle-v1.7.3.bin.fs86220fs.noheader insert 419 functions at 140
# bcf-gateway-usb-dongle-v1.7.4.bin.fs85980fs.noheader insert 457 functions at 141
# bcf-gateway-usb-dongle-v1.8.0.bin.fs86396fs.noheader insert 425 functions at 142
# bcf-gateway-usb-dongle-v1.9.0.bin.fs88880fs.noheader insert 451 functions at 143
# bcf-generic-node-battery-mini-v1.5.0.bin.fs87236fs.noheader insert 387 functions at 144
# bcf-generic-node-battery-mini-v1.5.5.bin.fs87708fs.noheader insert 367 functions at 145
# bcf-generic-node-battery-mini-v1.5.6.bin.fs87964fs.noheader insert 359 functions at 146
# bcf-generic-node-battery-mini-v1.7.2.bin.fs89372fs.noheader insert 382 functions at 147
# bcf-generic-node-battery-mini-v1.7.3.bin.fs89388fs.noheader insert 235 functions at 148
# bcf-generic-node-battery-mini-v1.7.4.bin.fs89324fs.noheader insert 354 functions at 149
# bcf-generic-node-battery-mini-v1.7.5.bin.fs90204fs.noheader insert 397 functions at 150
# bcf-generic-node-battery-standard-v1.5.0.bin.fs87236fs.noheader insert 0 functions at 151
# bcf-generic-node-battery-standard-v1.5.5.bin.fs87716fs.noheader insert 0 functions at 152
# bcf-generic-node-battery-standard-v1.5.6.bin.fs87964fs.noheader insert 0 functions at 153
# bcf-generic-node-battery-standard-v1.7.2.bin.fs89380fs.noheader insert 0 functions at 154
# bcf-generic-node-battery-standard-v1.7.3.bin.fs89396fs.noheader insert 0 functions at 155
# bcf-generic-node-battery-standard-v1.7.4.bin.fs89332fs.noheader insert 2 functions at 156
# bcf-generic-node-battery-standard-v1.7.5.bin.fs90204fs.noheader insert 0 functions at 157
# bcf-generic-node-battery-v1.10.0.bin.fs98668fs.noheader insert 447 functions at 158
# bcf-generic-node-battery-v1.8.0.bin.fs95980fs.noheader insert 431 functions at 159
# bcf-generic-node-battery-v1.9.0.bin.fs98332fs.noheader insert 442 functions at 160
# bcf-generic-node-power-module-rgb150-v1.10.0.bin.fs125076fs.noheader insert 479 functions at 161
# bcf-generic-node-power-module-rgb150-v1.5.0.bin.fs113748fs.noheader insert 382 functions at 162
# bcf-generic-node-power-module-rgb150-v1.5.5.bin.fs114420fs.noheader insert 382 functions at 163
# bcf-generic-node-power-module-rgb150-v1.5.6.bin.fs114468fs.noheader insert 0 functions at 164
# bcf-generic-node-power-module-rgb150-v1.7.2.bin.fs115860fs.noheader insert 404 functions at 165
# bcf-generic-node-power-module-rgb150-v1.7.3.bin.fs115852fs.noheader insert 401 functions at 166
# bcf-generic-node-power-module-rgb150-v1.7.4.bin.fs115788fs.noheader insert 391 functions at 167
# bcf-generic-node-power-module-rgb150-v1.7.5.bin.fs116172fs.noheader insert 417 functions at 168
# bcf-generic-node-power-module-rgb150-v1.8.0.bin.fs121996fs.noheader insert 456 functions at 169
# bcf-generic-node-power-module-rgb150-v1.9.0.bin.fs124740fs.noheader insert 480 functions at 170
# bcf-generic-node-power-module-rgb300-v1.10.0.bin.fs125084fs.noheader insert 472 functions at 171
# bcf-generic-node-power-module-rgb300-v1.5.0.bin.fs113748fs.noheader insert 375 functions at 172
# bcf-generic-node-power-module-rgb300-v1.5.5.bin.fs114420fs.noheader insert 379 functions at 173
# bcf-generic-node-power-module-rgb300-v1.5.6.bin.fs114468fs.noheader insert 0 functions at 174
# bcf-generic-node-power-module-rgb300-v1.7.2.bin.fs115860fs.noheader insert 400 functions at 175
# bcf-generic-node-power-module-rgb300-v1.7.3.bin.fs115860fs.noheader insert 162 functions at 176
# bcf-generic-node-power-module-rgb300-v1.7.4.bin.fs115796fs.noheader insert 388 functions at 177
# bcf-generic-node-power-module-rgb300-v1.7.5.bin.fs116180fs.noheader insert 405 functions at 178
# bcf-generic-node-power-module-rgb300-v1.8.0.bin.fs121996fs.noheader insert 452 functions at 179
# bcf-generic-node-power-module-rgb300-v1.9.0.bin.fs124748fs.noheader insert 467 functions at 180
# bcf-generic-node-power-module-rgbw144-v1.10.0.bin.fs125076fs.noheader insert 0 functions at 181
# bcf-generic-node-power-module-rgbw144-v1.5.0.bin.fs113748fs.noheader insert 0 functions at 182
# bcf-generic-node-power-module-rgbw144-v1.5.5.bin.fs114420fs.noheader insert 0 functions at 183
# bcf-generic-node-power-module-rgbw144-v1.5.6.bin.fs114468fs.noheader insert 0 functions at 184
# bcf-generic-node-power-module-rgbw144-v1.7.2.bin.fs115868fs.noheader insert 0 functions at 185
# bcf-generic-node-power-module-rgbw144-v1.7.3.bin.fs115860fs.noheader insert 0 functions at 186
# bcf-generic-node-power-module-rgbw144-v1.7.4.bin.fs115796fs.noheader insert 0 functions at 187
# bcf-generic-node-power-module-rgbw144-v1.7.5.bin.fs116172fs.noheader insert 0 functions at 188
# bcf-generic-node-power-module-rgbw144-v1.8.0.bin.fs121996fs.noheader insert 0 functions at 189
# bcf-generic-node-power-module-rgbw144-v1.9.0.bin.fs124740fs.noheader insert 0 functions at 190
# bcf-generic-node-power-module-rgbw72-v1.10.0.bin.fs125076fs.noheader insert 0 functions at 191
# bcf-generic-node-power-module-rgbw72-v1.5.0.bin.fs113748fs.noheader insert 0 functions at 192
# bcf-generic-node-power-module-rgbw72-v1.5.5.bin.fs114420fs.noheader insert 0 functions at 193
# bcf-generic-node-power-module-rgbw72-v1.5.6.bin.fs114468fs.noheader insert 0 functions at 194
# bcf-generic-node-power-module-rgbw72-v1.7.2.bin.fs115860fs.noheader insert 0 functions at 195
# bcf-generic-node-power-module-rgbw72-v1.7.3.bin.fs115852fs.noheader insert 0 functions at 196
# bcf-generic-node-power-module-rgbw72-v1.7.4.bin.fs115788fs.noheader insert 0 functions at 197
# bcf-generic-node-power-module-rgbw72-v1.7.5.bin.fs116172fs.noheader insert 0 functions at 198
# bcf-generic-node-power-module-rgbw72-v1.8.0.bin.fs121996fs.noheader insert 0 functions at 199
# bcf-generic-node-power-module-rgbw72-v1.9.0.bin.fs124740fs.noheader insert 0 functions at 200
# bcf-infra-grid-lcd-mirror-v1.0.0.bin.fs67292fs.noheader insert 317 functions at 201
# bcf-infra-grid-lcd-mirror-v1.1.0.bin.fs58828fs.noheader insert 273 functions at 202
# bcf-lcd-clock-with-stopwatch-v1.0.0.bin.fs79712fs.noheader insert 338 functions at 203
# bcf-lcd-clock-with-stopwatch-v1.0.1.bin.fs79384fs.noheader insert 312 functions at 204
# bcf-lcd-maxbotix-ultrasound-distance-v1.0.0.bin.fs75916fs.noheader insert 282 functions at 205
# bcf-lcd-qrcode-v1.0.0.bin.fs75412fs.noheader insert 374 functions at 206
# bcf-lcd-qrcode-v1.1.0.bin.fs44220fs.noheader insert 199 functions at 207
# bcf-lora-1wire-thermometer-v1.0.0.bin.fs64268fs.noheader insert 322 functions at 208
# bcf-lora-1wire-thermometer-v1.1.0.bin.fs64652fs.noheader insert 285 functions at 209
# bcf-lora-1wire-thermometer-v1.2.0.bin.fs65368fs.noheader insert 286 functions at 210
# bcf-lora-1wire-thermometer-v1.2.1.bin.fs65296fs.noheader insert 291 functions at 211
# bcf-lora-1wire-thermometer-v1.2.2.bin.fs65296fs.noheader insert 286 functions at 212
# bcf-lora-climate-monitor-v1.0.0.bin.fs68440fs.noheader insert 327 functions at 213
# bcf-lora-climate-monitor-v1.1.0.bin.fs69644fs.noheader insert 303 functions at 214
# bcf-lora-climate-monitor-v1.2.0.bin.fs69804fs.noheader insert 300 functions at 215
# bcf-lora-climate-monitor-v1.3.0.bin.fs71384fs.noheader insert 303 functions at 216
# bcf-lora-climate-pir-co2-v1.0.0.bin.fs72864fs.noheader insert 318 functions at 217
# bcf-lora-climate-pir-co2-v1.0.1.bin.fs74600fs.noheader insert 317 functions at 218
# bcf-lora-climate-pir-co2-v1.0.2.bin.fs75096fs.noheader insert 321 functions at 219
# bcf-lora-iaq-monitor-1.0.2.bin.fs71888fs.noheader insert 318 functions at 220
# bcf-lora-pulse-counter-v1.0.2.bin.fs55244fs.noheader insert 224 functions at 221
# bcf-lora-pulse-counter-v1.1.0.bin.fs67140fs.noheader insert 284 functions at 222
# bcf-lora-push-button-v1.0.0.bin.fs65536fs.noheader insert 282 functions at 223
# bcf-lora-tester-lcd-gps-ttnmapper-v1.0.0.bin.fs87680fs.noheader insert 416 functions at 224
# bcf-lora-tester-lcd-gps-ttnmapper-v1.0.1.bin.fs79592fs.noheader insert 351 functions at 225
# bcf-lora-tester-lcd-gps-ttnmapper-v1.0.2.bin.fs76144fs.noheader insert 294 functions at 226
# bcf-lora-tester-lcd-gps-ttnmapper-v1.0.3.bin.fs76160fs.noheader insert 216 functions at 227
# bcf-night-lamp-v1.0.0.bin.fs47620fs.noheader insert 265 functions at 228
# bcf-ping-pong-table-v1.0.0.bin.fs24180fs.noheader insert 131 functions at 229
# bcf-radio-8-ball-v1.0.0.bin.fs46636fs.noheader insert 251 functions at 230
# bcf-radio-air-quality-monitor-v1.0.1.bin.fs92860fs.noheader insert 405 functions at 231
# bcf-radio-air-quality-monitor-v1.0.2.bin.fs93924fs.noheader insert 394 functions at 232
# bcf-radio-air-quality-monitor-v1.0.3.bin.fs93924fs.noheader insert 0 functions at 233
# bcf-radio-air-quality-monitor-v1.1.0.bin.fs94332fs.noheader insert 406 functions at 234
# bcf-radio-burglar-alarm-v1.0.0.bin.fs46340fs.noheader insert 253 functions at 235
# bcf-radio-burglar-alarm-v1.1.0.bin.fs46340fs.noheader insert 0 functions at 236
# bcf-radio-climate-monitor-v1.3.0.bin.fs46540fs.noheader insert 247 functions at 237
# bcf-radio-climate-monitor-v1.4.0.bin.fs49108fs.noheader insert 259 functions at 238
# bcf-radio-climate-monitor-v1.5.0.bin.fs50140fs.noheader insert 213 functions at 239
# bcf-radio-co2-monitor-v1.4.0.bin.fs51352fs.noheader insert 271 functions at 240
# bcf-radio-co2-monitor-v1.5.0.bin.fs54288fs.noheader insert 294 functions at 241
# bcf-radio-co2-monitor-v1.5.1.bin.fs54320fs.noheader insert 273 functions at 242
# bcf-radio-co2-voc-lp-monitor-v1.2.0.bin.fs56688fs.noheader insert 331 functions at 243
# bcf-radio-door-lock-v1.0.0.bin.fs45264fs.noheader insert 240 functions at 244
# bcf-radio-door-lock-v1.1.0.bin.fs45264fs.noheader insert 0 functions at 245
# bcf-radio-door-sensor-v0.1.0.bin.fs65448fs.noheader insert 338 functions at 246
# bcf-radio-door-sensor-v0.2.0.bin.fs65944fs.noheader insert 316 functions at 247
# bcf-radio-ds18b20-with-lcd-v1.0.0.bin.fs87612fs.noheader insert 373 functions at 248
# bcf-radio-ds18b20-with-lcd-v1.1.0.bin.fs87940fs.noheader insert 376 functions at 249
# bcf-radio-fingerprint-sensor.bin.fs48296fs.noheader insert 256 functions at 250
# bcf-radio-flood-detector-v1.3.0.bin.fs44280fs.noheader insert 235 functions at 251
# bcf-radio-fridge-monitor-v1.0.0.bin.fs48516fs.noheader insert 267 functions at 252
# bcf-radio-fridge-monitor-v1.1.0.bin.fs48516fs.noheader insert 0 functions at 253
# bcf-radio-infragrid-sensor-v1.0.0.bin.fs46700fs.noheader insert 246 functions at 254
# bcf-radio-key-code-v1.0.0.bin.fs45200fs.noheader insert 264 functions at 255
# bcf-radio-key-code-v1.1.0.bin.fs45200fs.noheader insert 0 functions at 256
# bcf-radio-lcd-as504x-absolute-encoder-v1.0.0.bin.fs80860fs.noheader insert 360 functions at 257
# bcf-radio-lcd-thermostat-v1.4.0.bin.fs89968fs.noheader insert 345 functions at 258
# bcf-radio-modbus-relay-v1.0.1.bin.fs45476fs.noheader insert 245 functions at 259
# bcf-radio-motion-detector-v1.3.0.bin.fs44352fs.noheader insert 233 functions at 260
# bcf-radio-motion-detector-v1.4.0.bin.fs75388fs.noheader insert 418 functions at 261
# bcf-radio-move-detector-x-axis-v1.0.0.bin.fs46544fs.noheader insert 241 functions at 262
# bcf-radio-move-detector-y-axis-v1.0.0.bin.fs46544fs.noheader insert 0 functions at 263
# bcf-radio-move-detector-z-axis-v1.0.0.bin.fs46544fs.noheader insert 0 functions at 264
# bcf-radio-music-player-v1.0.0.bin.fs44116fs.noheader insert 227 functions at 265
# bcf-radio-music-player-v1.0.1.bin.fs44116fs.noheader insert 0 functions at 266
# bcf-radio-netio-lcd-monitor-v1.0.0.bin.fs73380fs.noheader insert 356 functions at 267
# bcf-radio-netio-lcd-monitor-v1.0.1.bin.fs73412fs.noheader insert 333 functions at 268
# bcf-radio-night-lamp-v1.0.0.bin.fs46948fs.noheader insert 251 functions at 269
# bcf-radio-night-lamp-v1.1.0.bin.fs46948fs.noheader insert 0 functions at 270
# bcf-radio-pool-sensor-v1.0.0.bin.fs70680fs.noheader insert 370 functions at 271
# bcf-radio-pool-sensor-v1.1.0.bin.fs71880fs.noheader insert 388 functions at 272
# bcf-radio-power-controller-rgb150-v1.4.1.bin.fs50592fs.noheader insert 268 functions at 273
# bcf-radio-power-controller-rgb150-v1.4.2.bin.fs51360fs.noheader insert 265 functions at 274
# bcf-radio-power-controller-rgbw144-v1.4.1.bin.fs50592fs.noheader insert 0 functions at 275
# bcf-radio-power-controller-rgbw144-v1.4.2.bin.fs51360fs.noheader insert 0 functions at 276
# bcf-radio-power-controller-rgbw36-v1.4.1.bin.fs50592fs.noheader insert 0 functions at 277
# bcf-radio-power-controller-rgbw36-v1.4.2.bin.fs51360fs.noheader insert 0 functions at 278
# bcf-radio-power-controller-rgbw72-v1.4.1.bin.fs50592fs.noheader insert 0 functions at 279
# bcf-radio-power-controller-rgbw72-v1.4.2.bin.fs51360fs.noheader insert 0 functions at 280
# bcf-radio-presenter-v1.0.0.bin.fs46672fs.noheader insert 236 functions at 281
# bcf-radio-presenter-v1.1.0.bin.fs65880fs.noheader insert 327 functions at 282
# bcf-radio-presenter-v1.2.0.bin.fs65720fs.noheader insert 340 functions at 283
# bcf-radio-pulse-counter-v1.0.0.bin.fs44164fs.noheader insert 234 functions at 284
# bcf-radio-push-button-v1.1.4.bin.fs43700fs.noheader insert 229 functions at 285
# bcf-radio-push-button-v1.3.0.bin.fs43684fs.noheader insert 184 functions at 286
# bcf-radio-push-button-v1.4.0.bin.fs47832fs.noheader insert 263 functions at 287
# bcf-radio-push-button-v1.4.1.bin.fs48116fs.noheader insert 289 functions at 288
# bcf-radio-qr-wifi-terminal-1.0.3.bin.fs89128fs.noheader insert 431 functions at 289
# bcf-radio-qr-wifi-terminal-v1.0.3.bin.fs89128fs.noheader insert 0 functions at 290
# bcf-radio-qr-wifi-terminal-v1.0.4.bin.fs89128fs.noheader insert 0 functions at 291
# bcf-radio-shock-sensor-v1.1.0.bin.fs46904fs.noheader insert 291 functions at 292
# bcf-radio-smart-doorbell-v1.0.1.bin.fs45648fs.noheader insert 234 functions at 293
# bcf-radio-smart-doorbell-v1.0.2.bin.fs45648fs.noheader insert 0 functions at 294
# bcf-radio-soil-sensor-v1.0.0.bin.fs47256fs.noheader insert 259 functions at 295
# bcf-radio-soil-sensor-v1.1.0.bin.fs68700fs.noheader insert 359 functions at 296
# bcf-radio-soil-sensor-v1.2.0.bin.fs68772fs.noheader insert 231 functions at 297
# bcf-radio-soil-sensor-v1.3.0.bin.fs68772fs.noheader insert 231 functions at 298
# bcf-radio-soil-sensor-v1.4.0.bin.fs68500fs.noheader insert 362 functions at 299
# bcf-radio-spinning-game-v1.0.0.bin.fs46732fs.noheader insert 235 functions at 300
# bcf-radio-spirit-level-v1.0.1.bin.fs46368fs.noheader insert 241 functions at 301
# bcf-radio-still-position-detector-v1.0.1.bin.fs46804fs.noheader insert 247 functions at 302
# bcf-radio-still-position-detector-v1.0.2.bin.fs47376fs.noheader insert 210 functions at 303
# bcf-radio-turris-lcd-monitor-v1.0.0.bin.fs97836fs.noheader insert 453 functions at 304
# bcf-radio-turris-lcd-monitor-v1.0.1.bin.fs97828fs.noheader insert 0 functions at 305
# bcf-radio-turris-lcd-monitor-v1.0.2.bin.fs97828fs.noheader insert 259 functions at 306
# bcf-radio-turris-lcd-monitor-v1.0.3.bin.fs97828fs.noheader insert 0 functions at 307
# bcf-radio-vibration-monitor-v1.0.1.bin.fs44868fs.noheader insert 169 functions at 308
# bcf-radio-vibration-monitor-v1.0.2.bin.fs44860fs.noheader insert 0 functions at 309
# bcf-radio-voc-lp-sensor-v1.0.0.bin.fs92952fs.noheader insert 439 functions at 310
# bcf-radio-voc-lp-sensor-v1.0.1.bin.fs93008fs.noheader insert 345 functions at 311
# bcf-radio-voc-lp-sensor-v1.0.2.bin.fs93008fs.noheader insert 0 functions at 312
# bcf-radio-voc-sensor-v1.0.0.bin.fs88264fs.noheader insert 379 functions at 313
# bcf-radio-voc-sensor-v1.1.0.bin.fs92864fs.noheader insert 400 functions at 314
# bcf-radio-washing-machine-monitor-v1.0.0.bin.fs46760fs.noheader insert 241 functions at 315
# bcf-radio-wind-and-rain-station-v1.0.0.bin.fs82420fs.noheader insert 437 functions at 316
# bcf-radio-wind-and-rain-station-v1.0.1.bin.fs82268fs.noheader insert 393 functions at 317
# bcf-radio-window-servo-control-v1.0.0.bin.fs73488fs.noheader insert 399 functions at 318
# bcf-radio-zero-g-meter-v1.0.0.bin.fs46732fs.noheader insert 242 functions at 319
# bcf-sigfox-climate-monitor-v1.0.1.bin.fs37360fs.noheader insert 176 functions at 320
# bcf-sigfox-co2-monitor-v1.1.0.bin.fs43408fs.noheader insert 222 functions at 321
# bcf-sigfox-garage-door-guard-v1.0.0.bin.fs36660fs.noheader insert 178 functions at 322
# bcf-sigfox-garage-door-guard-v1.0.1.bin.fs36660fs.noheader insert 0 functions at 323
# bcf-sigfox-motion-detector-v1.1.0.bin.fs39896fs.noheader insert 191 functions at 324
# bcf-sigfox-pir-counter-v1.0.0.bin.fs38696fs.noheader insert 191 functions at 325
# bcf-sigfox-pir-counter-v1.1.0.bin.fs38736fs.noheader insert 159 functions at 326
# bcf-sigfox-pulse-counter-v1.1.0.bin.fs32396fs.noheader insert 133 functions at 327
# bcf-sigfox-push-button-v1.0.0.bin.fs21632fs.noheader insert 98 functions at 328
# bolt-2022.03.bin.fs235172fs.noheader insert 0 functions at 329
# bolt-2022.05.bin.fs235756fs.noheader insert 0 functions at 330
# bolt-2022.09.bin.fs246804fs.noheader insert 0 functions at 331
# bolt-2022.12.bin.fs252228fs.noheader insert 0 functions at 332
# bolt-2023.02.bin.fs254448fs.noheader insert 0 functions at 333
# bolt-2023.06.bin.fs257596fs.noheader insert 0 functions at 334
# bolt-2023.07.bin.fs257652fs.noheader insert 0 functions at 335
# bolt_nrf-2022.03.bin.fs64896fs.noheader insert 326 functions at 336
# bolt_nrf-2022.05.bin.fs64972fs.noheader insert 166 functions at 337
# bolt_nrf-2022.09.bin.fs65332fs.noheader insert 163 functions at 338
# bolt_nrf-2022.12.bin.fs67740fs.noheader insert 328 functions at 339
# bolt_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 340
# bolt_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 341
# bolt_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 342
# boot64.bin.fs8192fs.noheader insert 0 functions at 343
# boot64a.bin.fs8192fs.noheader insert 0 functions at 344
# boot64b.bin.fs8192fs.noheader insert 0 functions at 345
# cf1-2016.02.bin.fs86152fs.noheader insert 297 functions at 346
# cf1-2016.09.bin.fs87328fs.noheader insert 273 functions at 347
# cf1-2016.09.bin.fs87328fs.noheader insert 0 functions at 348
# cf1-2017.04.bin.fs90112fs.noheader insert 282 functions at 349
# cf1-2017.05.bin.fs90260fs.noheader insert 146 functions at 350
# cf1-2017.05.bin.fs90260fs.noheader insert 0 functions at 351
# cf1-2017.06.bin.fs90788fs.noheader insert 173 functions at 352
# cf2-2015.08.1.bin.fs75152fs.noheader insert 0 functions at 353
# cf2-2016.02.bin.fs127792fs.noheader insert 0 functions at 354
# cf2-2016.09.bin.fs144640fs.noheader insert 0 functions at 355
# cf2-2016.09.bin.fs144640fs.noheader insert 0 functions at 356
# cf2-2017.04.bin.fs160192fs.noheader insert 0 functions at 357
# cf2-2017.05.bin.fs183624fs.noheader insert 0 functions at 358
# cf2-2017.06.bin.fs202392fs.noheader insert 0 functions at 359
# cf2-2018.01.1.bin.fs210396fs.noheader insert 0 functions at 360
# cf2-2018.10.bin.fs271892fs.noheader insert 0 functions at 361
# cf2-2018.12.bin.fs190476fs.noheader insert 0 functions at 362
# cf2-2019.01.bin.fs190548fs.noheader insert 0 functions at 363
# cf2-2019.02.bin.fs190580fs.noheader insert 0 functions at 364
# cf2-2019.09.bin.fs196660fs.noheader insert 0 functions at 365
# cf2-2020.02.bin.fs202888fs.noheader insert 0 functions at 366
# cf2-2020.04.bin.fs218340fs.noheader insert 0 functions at 367
# cf2-2020.06.bin.fs219052fs.noheader insert 0 functions at 368
# cf2-2020.09.bin.fs226684fs.noheader insert 0 functions at 369
# cf2-2021.01.bin.fs235076fs.noheader insert 0 functions at 370
# cf2-2021.03.bin.fs237544fs.noheader insert 0 functions at 371
# cf2-2021.06.bin.fs239656fs.noheader insert 0 functions at 372
# cf2-2022.01.bin.fs250656fs.noheader insert 0 functions at 373
# cf2-2022.03.bin.fs242760fs.noheader insert 0 functions at 374
# cf2-2022.05.bin.fs243344fs.noheader insert 0 functions at 375
# cf2-2022.09.bin.fs254800fs.noheader insert 0 functions at 376
# cf2-2022.12.bin.fs260144fs.noheader insert 0 functions at 377
# cf2-2023.02.bin.fs262364fs.noheader insert 0 functions at 378
# cf2-2023.06.bin.fs265496fs.noheader insert 0 functions at 379
# cf2-2023.07.bin.fs265552fs.noheader insert 0 functions at 380
# cf2-kalman-2017.05.bin.fs197292fs.noheader insert 0 functions at 381
# cf2-nrf-2015.08.1.bin.fs46868fs.noheader insert 253 functions at 382
# cf2_nrf-2016.02.bin.fs46916fs.noheader insert 257 functions at 383
# cf2_nrf-2016.09.bin.fs61460fs.noheader insert 307 functions at 384
# cf2_nrf-2016.11.bin.fs61304fs.noheader insert 300 functions at 385
# cf2_nrf-2016.11.bin.fs61304fs.noheader insert 0 functions at 386
# cf2_nrf-2017.05.bin.fs61528fs.noheader insert 148 functions at 387
# cf2_nrf-2017.05.bin.fs61528fs.noheader insert 0 functions at 388
# cf2_nrf-2017.05.bin.fs61528fs.noheader insert 0 functions at 389
# cf2_nrf-2018.01.bin.fs61852fs.noheader insert 300 functions at 390
# cf2_nrf-2018.10.bin.fs61844fs.noheader insert 148 functions at 391
# cf2_nrf-2018.12.bin.fs61732fs.noheader insert 307 functions at 392
# cf2_nrf-2019.01.bin.fs61732fs.noheader insert 0 functions at 393
# cf2_nrf-2019.02.1.bin.fs62108fs.noheader insert 130 functions at 394
# cf2_nrf-2019.09.bin.fs62520fs.noheader insert 154 functions at 395
# cf2_nrf-2020.02.bin.fs63640fs.noheader insert 268 functions at 396
# cf2_nrf-2020.04.bin.fs64624fs.noheader insert 311 functions at 397
# cf2_nrf-2020.06.bin.fs64668fs.noheader insert 126 functions at 398
# cf2_nrf-2020.09.bin.fs64528fs.noheader insert 160 functions at 399
# cf2_nrf-2020.09.bin.fs64528fs.noheader insert 0 functions at 400
# cf2_nrf-2021.03.bin.fs64528fs.noheader insert 127 functions at 401
# cf2_nrf-2021.06.bin.fs64528fs.noheader insert 0 functions at 402
# cf2_nrf-2022.01.bin.fs64884fs.noheader insert 160 functions at 403
# cf2_nrf-2022.03.bin.fs64896fs.noheader insert 0 functions at 404
# cf2_nrf-2022.05.bin.fs64972fs.noheader insert 0 functions at 405
# cf2_nrf-2022.09.bin.fs65332fs.noheader insert 0 functions at 406
# cf2_nrf-2022.12.bin.fs67740fs.noheader insert 0 functions at 407
# cf2_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 408
# cf2_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 409
# cf2_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 410
# crazyflie1-2015.08.1.bin.fs63544fs.noheader insert 262 functions at 411
# crazyflie1-2015.1.bin.fs55516fs.noheader insert 263 functions at 412
# firmware.bin.fs46613fs.noheader insert 130 functions at 413
# firmware.bin.fs57741fs.noheader insert 194 functions at 414
# firmware.bin.fs57741fs.noheader insert 2 functions at 415
# firmware__2_.bin.fs65420fs.noheader insert 214 functions at 416
# flapper-2022.12.bin.fs254904fs.noheader insert 0 functions at 417
# flapper-2023.02.bin.fs257140fs.noheader insert 0 functions at 418
# flapper-2023.06.bin.fs260280fs.noheader insert 0 functions at 419
# flapper-2023.07.bin.fs260336fs.noheader insert 0 functions at 420
# flapper_nrf-2022.12.bin.fs67740fs.noheader insert 0 functions at 421
# flapper_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 422
# flapper_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 423
# flapper_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 424
# fw_TI_7_ver.2.bin.fs10388fs.noheader insert 54 functions at 425
# generic_boot20_pc13.bin.fs21140fs.noheader insert 0 functions at 426
# iTargetHost_APROM_v1.013_20200424_0132.bin.fs62208fs.noheader insert 229 functions at 427
# light_switch_proxy_server_nrf52832_xxAA_s132_6.0.0.bin.fs170620fs.noheader insert 1085 functions at 428
# load64.bin.fs354436fs.noheader insert 0 functions at 429
# load64b.bin.fs366840fs.noheader insert 0 functions at 430
# tag-2019.02.bin.fs181840fs.noheader insert 0 functions at 431
# tag-2019.09.bin.fs183172fs.noheader insert 0 functions at 432
# tag-2020.02.bin.fs189216fs.noheader insert 0 functions at 433
# tag-2020.04.bin.fs204460fs.noheader insert 4 functions at 434
# tag-2020.06.bin.fs205180fs.noheader insert 0 functions at 435
# tag-2020.09.bin.fs212788fs.noheader insert 0 functions at 436
# tag-2021.01.bin.fs221172fs.noheader insert 0 functions at 437
# tag-2021.03.bin.fs226972fs.noheader insert 0 functions at 438
# tag-2021.06.bin.fs229012fs.noheader insert 0 functions at 439
# tag-2022.01.bin.fs239804fs.noheader insert 0 functions at 440
# tag-2022.03.bin.fs233620fs.noheader insert 0 functions at 441
# tag-2022.05.bin.fs234188fs.noheader insert 0 functions at 442
# tag-2022.09.bin.fs245204fs.noheader insert 0 functions at 443
# tag-2022.12.bin.fs250620fs.noheader insert 0 functions at 444
# tag-2023.02.bin.fs252840fs.noheader insert 0 functions at 445
# tag-2023.06.bin.fs255972fs.noheader insert 0 functions at 446
# tag-2023.07.bin.fs256028fs.noheader insert 0 functions at 447
# tag_nrf-2019.02.1.bin.fs62108fs.noheader insert 0 functions at 448
# tag_nrf-2019.09.bin.fs62520fs.noheader insert 0 functions at 449
# tag_nrf-2020.02.bin.fs63640fs.noheader insert 0 functions at 450
# tag_nrf-2020.04.bin.fs64624fs.noheader insert 0 functions at 451
# tag_nrf-2020.06.bin.fs64668fs.noheader insert 0 functions at 452
# tag_nrf-2020.09.bin.fs64528fs.noheader insert 0 functions at 453
# tag_nrf-2020.09.bin.fs64528fs.noheader insert 0 functions at 454
# tag_nrf-2021.03.bin.fs64528fs.noheader insert 0 functions at 455
# tag_nrf-2021.06.bin.fs64528fs.noheader insert 0 functions at 456
# tag_nrf-2022.01.bin.fs64884fs.noheader insert 0 functions at 457
# tag_nrf-2022.03.bin.fs64896fs.noheader insert 0 functions at 458
# tag_nrf-2022.05.bin.fs64972fs.noheader insert 0 functions at 459
# tag_nrf-2022.09.bin.fs65332fs.noheader insert 0 functions at 460
# tag_nrf-2022.12.bin.fs67740fs.noheader insert 0 functions at 461
# tag_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 462
# tag_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 463
# tag_nrf-2023.02.bin.fs67740fs.noheader insert 0 functions at 464
# twr-gps-ice-v1.0.0.bin.fs53236fs.noheader insert 286 functions at 465
# twr-gps-ice-v1.0.1.bin.fs53372fs.noheader insert 269 functions at 466
# twr-gps-ice-v1.1.0.bin.fs82108fs.noheader insert 433 functions at 467
# twr-infra-grid-lcd-mirror-v1.2.0.bin.fs43976fs.noheader insert 197 functions at 468
# twr-lcd-climate-v.1.1.3.bin.fs76520fs.noheader insert 348 functions at 469
# twr-lcd-climate-v1.0.1.bin.fs76520fs.noheader insert 0 functions at 470
# twr-lcd-climate-v1.0.3.bin.fs76520fs.noheader insert 0 functions at 471
# twr-lcd-climate-v1.0.6.bin.fs76520fs.noheader insert 0 functions at 472
# twr-lcd-climate-v1.0.9.bin.fs76520fs.noheader insert 0 functions at 473
# twr-lcd-climate-v1.1.0.bin.fs76520fs.noheader insert 0 functions at 474
# twr-lcd-climate-with-voc-lp-v1.0.1.bin.fs77504fs.noheader insert 348 functions at 475
# twr-lcd-climate-with-voc-lp-v1.1.0.bin.fs77512fs.noheader insert 345 functions at 476
# twr-lcd-maxbotix-ultrasound-distance-v1.1.0.bin.fs61848fs.noheader insert 194 functions at 477
# twr-lcd-qrcode-v1.1.1.bin.fs44220fs.noheader insert 0 functions at 478
# twr-lora-1wire-thermometer-v1.3.0.bin.fs54336fs.noheader insert 261 functions at 479
# twr-lora-1wire-thermometer-v1.3.1.bin.fs78260fs.noheader insert 394 functions at 480
# twr-lora-class-c-relay-v1.0.0.bin.fs66496fs.noheader insert 302 functions at 481
# twr-lora-class-c-relay-v1.1.0.bin.fs67096fs.noheader insert 303 functions at 482
# twr-lora-class-c-relay-v1.2.0.bin.fs54580fs.noheader insert 260 functions at 483
# twr-lora-climate-monitor-analog-inputs-v1.1.0.bin.fs57696fs.noheader insert 277 functions at 484
# twr-lora-climate-monitor-v1.4.0.bin.fs57696fs.noheader insert 0 functions at 485
# twr-lora-climate-monitor-v1.4.1.bin.fs57688fs.noheader insert 279 functions at 486
# twr-lora-climate-monitor-v1.4.2.bin.fs57632fs.noheader insert 270 functions at 487
# twr-lora-climate-pir-co2-v1.1.1.bin.fs61424fs.noheader insert 289 functions at 488
# twr-lora-iaq-monitor-v1.1.0.bin.fs58600fs.noheader insert 284 functions at 489
# twr-lora-maxbotix-ultrasound-distance-v1.0.0.bin.fs53240fs.noheader insert 227 functions at 490
# twr-lora-maxbotix-ultrasound-distance-v1.0.1.bin.fs71340fs.noheader insert 366 functions at 491
# twr-lora-maxbotix-ultrasound-distance-v1.1.0.bin.fs71468fs.noheader insert 350 functions at 492
# twr-lora-soil-moisture-sensor-v1.0.0.bin.fs55200fs.noheader insert 261 functions at 493
# twr-lora-soil-moisture-sensor-v1.0.1.bin.fs73292fs.noheader insert 340 functions at 494
# twr-lora-soil-moisture-sensor-v1.1.0.bin.fs73420fs.noheader insert 332 functions at 495
# twr-lora-tester-lcd-gps-ttnmapper-v1.1.0.bin.fs62516fs.noheader insert 265 functions at 496
# twr-lora-tester-v1.10.0.bin.fs72548fs.noheader insert 287 functions at 497
# twr-lora-tester-v1.10.1.bin.fs72668fs.noheader insert 267 functions at 498
# twr-lora-tester-v1.11.0.bin.fs72452fs.noheader insert 295 functions at 499
# twr-lora-tester-v1.11.1.bin.fs72520fs.noheader insert 242 functions at 500
# twr-lora-tester-v1.12.0.bin.fs90268fs.noheader insert 402 functions at 501
# twr-lora-tester-v1.9.10.bin.fs71412fs.noheader insert 273 functions at 502
# twr-lora-tester-v1.9.5.bin.fs67956fs.noheader insert 262 functions at 503
# twr-lora-tester-v1.9.6.bin.fs68124fs.noheader insert 203 functions at 504
# twr-lora-tester-v1.9.7.bin.fs68268fs.noheader insert 263 functions at 505
# twr-lora-tester-v1.9.8.bin.fs68412fs.noheader insert 264 functions at 506
# twr-lora-tester-v1.9.9.bin.fs69908fs.noheader insert 274 functions at 507
# twr-okim-bps-hugo-v1.0.0.bin.fs75560fs.noheader insert 429 functions at 508
# twr-okim-bps-hugo-v1.1.0.bin.fs51868fs.noheader insert 295 functions at 509
# twr-ping-pong-table-v1.1.0.bin.fs37248fs.noheader insert 176 functions at 510
# twr-radio-1wire-thermometer-ice-v1.0.0.bin.fs48028fs.noheader insert 293 functions at 511
# twr-radio-1wire-thermometer-v1.0.1.bin.fs82128fs.noheader insert 467 functions at 512
# twr-radio-8-ball-v1.1.1.bin.fs51944fs.noheader insert 287 functions at 513
# twr-radio-air-quality-monitor-v1.2.0.bin.fs81440fs.noheader insert 367 functions at 514
# twr-radio-air-quality-monitor-v1.3.0.bin.fs98016fs.noheader insert 483 functions at 515
# twr-radio-burglar-alarm-v1.2.0.bin.fs51824fs.noheader insert 292 functions at 516
# twr-radio-climate-monitor-v1.6.0.bin.fs55608fs.noheader insert 322 functions at 517
# twr-radio-climate-monitor-v1.7.0.bin.fs44836fs.noheader insert 286 functions at 518
# twr-radio-co2-monitor-v1.6.0.bin.fs59760fs.noheader insert 332 functions at 519
# twr-radio-co2-voc-lp-monitor-v1.3.0.bin.fs62088fs.noheader insert 349 functions at 520
# twr-radio-door-lock-v1.2.0.bin.fs51360fs.noheader insert 282 functions at 521
# twr-radio-door-sensor-v1.0.0.bin.fs53368fs.noheader insert 286 functions at 522
# twr-radio-elevator-monitor-v1.0.0.bin.fs55920fs.noheader insert 298 functions at 523
# twr-radio-fingerprint-sensor-v1.1.0.bin.fs54144fs.noheader insert 281 functions at 524
# twr-radio-flood-detector-v1.4.0.bin.fs52344fs.noheader insert 287 functions at 525
# twr-radio-fridge-monitor-v1.2.0.bin.fs55032fs.noheader insert 315 functions at 526
# twr-radio-fuel-cell-module-v1.0.0.bin.fs86872fs.noheader insert 331 functions at 527
# twr-radio-fuel-cell-module-v1.0.1.bin.fs86872fs.noheader insert 0 functions at 528
# twr-radio-fuel-cell-module-v1.0.2.bin.fs87556fs.noheader insert 335 functions at 529
# twr-radio-fuel-cell-module-v1.1.0.bin.fs87556fs.noheader insert 0 functions at 530
# twr-radio-ir-co2-monitor-v1.0.0.bin.fs50664fs.noheader insert 277 functions at 531
# twr-radio-ir-co2-monitor-v1.0.1.bin.fs51328fs.noheader insert 275 functions at 532
# twr-radio-ir-co2-monitor-v1.0.2.bin.fs44888fs.noheader insert 259 functions at 533
# twr-radio-ir-co2-monitor-v1.0.3.bin.fs45092fs.noheader insert 250 functions at 534
# twr-radio-key-code-v1.2.0.bin.fs50688fs.noheader insert 271 functions at 535
# twr-radio-lcd-co2-voc-lp-v1.0.0.bin.fs74280fs.noheader insert 358 functions at 536
# twr-radio-lcd-thermostat-v1.5.0.bin.fs79548fs.noheader insert 320 functions at 537
# twr-radio-lcd-thermostat-v1.6.0.bin.fs96120fs.noheader insert 359 functions at 538
# twr-radio-maxbotix-ultrasound-distance-v1.0.0.bin.fs48640fs.noheader insert 270 functions at 539
# twr-radio-modbus-relay-v1.1.0.bin.fs50496fs.noheader insert 276 functions at 540
# twr-radio-motion-detector-v1.5.0.bin.fs63032fs.noheader insert 346 functions at 541
# twr-radio-motion-detector-v1.6.0.bin.fs79348fs.noheader insert 457 functions at 542
# twr-radio-music-player-v1.1.0.bin.fs49932fs.noheader insert 248 functions at 543
# twr-radio-netio-lcd-monitor-v1.1.0.bin.fs60632fs.noheader insert 311 functions at 544
# twr-radio-netio-lcd-monitor-v1.2.0.bin.fs60632fs.noheader insert 0 functions at 545
# twr-radio-pm-sensor-v1.0.0.bin.fs50304fs.noheader insert 273 functions at 546
# twr-radio-power-controller-rgb150-1.5.1.bin.fs57376fs.noheader insert 314 functions at 547
# twr-radio-power-controller-rgb150-v1.5.0.bin.fs57376fs.noheader insert 2 functions at 548
# twr-radio-power-controller-rgb150-v1.5.2.bin.fs57376fs.noheader insert 0 functions at 549
# twr-radio-power-controller-rgb150-v1.5.3.bin.fs46584fs.noheader insert 282 functions at 550
# twr-radio-power-controller-rgb150-v1.6.0.bin.fs52296fs.noheader insert 288 functions at 551
# twr-radio-power-controller-rgbw144-1.5.1.bin.fs57376fs.noheader insert 0 functions at 552
# twr-radio-power-controller-rgbw144-v1.5.0.bin.fs57376fs.noheader insert 0 functions at 553
# twr-radio-power-controller-rgbw144-v1.5.2.bin.fs57376fs.noheader insert 0 functions at 554
# twr-radio-power-controller-rgbw144-v1.5.3.bin.fs46584fs.noheader insert 0 functions at 555
# twr-radio-power-controller-rgbw144-v1.6.0.bin.fs52296fs.noheader insert 0 functions at 556
# twr-radio-power-controller-rgbw36-1.5.1.bin.fs57376fs.noheader insert 0 functions at 557
# twr-radio-power-controller-rgbw36-v1.5.0.bin.fs57376fs.noheader insert 0 functions at 558
# twr-radio-power-controller-rgbw36-v1.5.2.bin.fs57376fs.noheader insert 0 functions at 559
# twr-radio-power-controller-rgbw36-v1.5.3.bin.fs46584fs.noheader insert 0 functions at 560
# twr-radio-power-controller-rgbw36-v1.6.0.bin.fs52296fs.noheader insert 0 functions at 561
# twr-radio-power-controller-rgbw72-1.5.1.bin.fs57376fs.noheader insert 0 functions at 562
# twr-radio-power-controller-rgbw72-v1.5.0.bin.fs57376fs.noheader insert 0 functions at 563
# twr-radio-power-controller-rgbw72-v1.5.2.bin.fs57376fs.noheader insert 0 functions at 564
# twr-radio-power-controller-rgbw72-v1.5.3.bin.fs46584fs.noheader insert 0 functions at 565
# twr-radio-power-controller-rgbw72-v1.6.0.bin.fs52296fs.noheader insert 0 functions at 566
# twr-radio-power-gps-voc-flood-v1.0.0.bin.fs57252fs.noheader insert 294 functions at 567
# twr-radio-power-gps-voc-flood-v1.0.1.bin.fs57252fs.noheader insert 0 functions at 568
# twr-radio-presenter-v1.3.0.bin.fs52304fs.noheader insert 284 functions at 569
# twr-radio-pt1000-thermometer-v1.0.1.bin.fs52352fs.noheader insert 283 functions at 570
# twr-radio-pt1000-thermometer-v1.2.0.bin.fs41624fs.noheader insert 245 functions at 571
# twr-radio-pulse-counter-v1.1.0.bin.fs52312fs.noheader insert 287 functions at 572
# twr-radio-push-button-v1.5.0.bin.fs53332fs.noheader insert 294 functions at 573
# twr-radio-push-button-v1.5.2.bin.fs53332fs.noheader insert 0 functions at 574
# twr-radio-push-button-v1.5.3.bin.fs42556fs.noheader insert 251 functions at 575
# twr-radio-qr-wifi-terminal-v1.1.0.bin.fs67248fs.noheader insert 342 functions at 576
# twr-radio-sensor-module-analog-inputs-v1.0.0.bin.fs45068fs.noheader insert 260 functions at 577
# twr-radio-shock-sensor-v1.1.1.bin.fs46904fs.noheader insert 0 functions at 578
# twr-radio-shock-sensor-v1.1.2.bin.fs46908fs.noheader insert 0 functions at 579
# twr-radio-soil-sensor-v1.5.0.bin.fs54732fs.noheader insert 310 functions at 580
# twr-radio-soil-sensor-v1.5.1.bin.fs54860fs.noheader insert 297 functions at 581
# twr-radio-soil-sensor-v1.5.2.bin.fs71432fs.noheader insert 410 functions at 582
# twr-radio-spinning-game-v1.1.0.bin.fs52048fs.noheader insert 281 functions at 583
# twr-radio-spirit-level-v1.1.0.bin.fs51844fs.noheader insert 288 functions at 584
# twr-radio-stem-power-controller-v1.0.0.bin.fs54024fs.noheader insert 294 functions at 585
# twr-radio-still-position-detector-v1.1.0.bin.fs52696fs.noheader insert 291 functions at 586
# twr-radio-turris-lcd-monitor-v1.1.0.bin.fs75860fs.noheader insert 349 functions at 587
# twr-radio-vibration-monitor-v1.1.0.bin.fs49672fs.noheader insert 267 functions at 588
# twr-radio-voc-lp-sensor-v1.1.0.bin.fs80272fs.noheader insert 368 functions at 589
# twr-radio-voc-sensor-v1.2.0.bin.fs79968fs.noheader insert 367 functions at 590
# twr-radio-washing-machine-monitor-v1.1.0.bin.fs52248fs.noheader insert 278 functions at 591
# twr-radio-wind-and-rain-station-v1.1.0.bin.fs60904fs.noheader insert 296 functions at 592
# twr-radio-window-servo-control-v1.1.0.bin.fs51256fs.noheader insert 281 functions at 593
# twr-radio-zero-g-meter-v1.1.0.bin.fs52048fs.noheader insert 282 functions at 594
# twr-sigfox-climate-monitor-v1.1.0.bin.fs47996fs.noheader insert 224 functions at 595
# twr-sigfox-garage-door-guard-v1.2.0.bin.fs49968fs.noheader insert 226 functions at 596
# twr-sigfox-pir-counter-v1.2.0.bin.fs46656fs.noheader insert 208 functions at 597
# twr-sigfox-pulse-counter-v1.2.0.bin.fs46216fs.noheader insert 202 functions at 598
# updfw_1_1_11.refw.fs421714fs.noheader insert 1773 functions at 599
# v1.0A.bin.fs60144fs.noheader insert 411 functions at 600
# v1.0B.bin.fs55960fs.noheader insert 394 functions at 601
# v1.0C.bin.fs55208fs.noheader insert 379 functions at 602

# %%
for file_ in project.getRootFolder().getFiles():
    print(file_.getName())

# %%
# Out:
# ghidra.base.project.GhidraProject@76a6f045

# %% [markdown]
# # END

# %%
files_ = []
for file_ in project.getRootFolder().getFiles():
    files_.append(file_.getName())

# %%
len(files_)
# Out:
# 603
